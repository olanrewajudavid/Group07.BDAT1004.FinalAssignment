# %%
# Import dependencies
import pandas as pd
import requests
from pymongo import MongoClient
import pymongo
from pprint import pprint
import csv
import json
from io import StringIO
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Connect to MongoDB server
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# confirm that our new database was created
print(client.list_database_names())
# Out:
# ['Bitcoin', 'Financial_Report', 'admin', 'classDB', 'config', 'fruits_db', 'local', 'uk_food']

# %%
# assign the database to a variable name
df= client['Financial_Report']

# %%
# Access the collection (replace 'data' with your collection name)
collection = df['data']

# %%
# Fetch all documents from the collection
cursor = collection.find({})

# %%
# Convert documents to list of dictionaries
documents = list(cursor)

# %%
# review a document in the financial collection
pprint(df.data.find_one())
# Out:
# {'  Sales ': ' $529,550.00 ',
#  ' COGS ': ' $393,380.00 ',
#  ' Discount Band ': ' None ',
#  ' Discounts ': ' $-   ',
#  ' Gross Sales ': ' $529,550.00 ',
#  ' Manufacturing Price ': ' $3.00 ',
#  ' Month Name ': ' December ',
#  ' Product ': ' Carretera ',
#  ' Profit ': ' $136,170.00 ',
#  ' Sale Price ': ' $350.00 ',
#  'Country': 'Germany',
#  'Date': '2014-12-01',
#  'Month Number': '12',
#  'Segment': 'Government',
#  'Units Sold': '1513',
#  'Year': '2014',
#  '_id': ObjectId('6603af8df1798c217086ca71')}

# %%
# Convert list of dictionaries to pandas DataFrame
data_df = pd.DataFrame(documents)
# Display DataFrame
data_df
# Out:
#                           _id           Segment                   Country  \
# 0    6603af8df1798c217086ca71        Government                   Germany
# 1    6603af8df1798c217086ca72        Government                    Canada
# 2    6603af8df1798c217086ca73    Small Business                    Mexico
# 3    6603af8df1798c217086ca74        Enterprise                    Canada
# 4    6603af8df1798c217086ca75  Channel Partners                   Germany
# ..                        ...               ...                       ...
# 696  6603af8df1798c217086cd29        Enterprise                   Germany
# 697  6603af8df1798c217086cd2a        Government                    Canada
# 698  6603af8df1798c217086cd2b        Government                    Mexico
# 699  6603af8df1798c217086cd2c  Channel Partners  United States of America
# 700  6603af8df1798c217086cd2d    Small Business                    Mexico
#
#         Product   Discount Band  Units Sold  Manufacturing Price   \
# ...

# %%
#printing out the columns to reduce it
print(data_df.columns)
# Out:
# Index(['_id', 'Segment', 'Country', ' Product ', ' Discount Band ',
#        'Units Sold', ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ',
#        ' Discounts ', '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
#rewriting the column titles
columns_to_clean = [' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ', '  Sales ',' COGS ', ' Profit ']

# Loop through the columns to remove $ sign
for col in columns_to_clean:
    data_df[col] = pd.to_numeric(data_df[col].replace('[^0-9\.-]', '', regex=True), errors='coerce')

# %%
# Rename columns for readability
updated_df = data_df.rename(columns={"_id": "id",
                                                  "Segment": "Segment",
                                                  "Country": "Country",
                                                  " Product ": "Product",
                                                  " Discount Band ": "Discount Band",
                                                  "Units Sold": "Units Sold",
                                                  " Manufacturing Price ": "Manufacturing Price",
                                                  "Sale Price": "Sale Price",
                                                  " Gross Sales ": "Gross Sales",
                                                  " Discounts ": "Discounts",
                                                  "  Sales ": "Sales",
                                                  " COGS ": "Cost of Goods Sold",
                                                  " Profit ": "Profit",
                                                  "Date": "Date",
                                                  "Month Number": "Month Number",
                                                  " Month Name ": "Month Name",
                                                  "Year": "Year"
                                                })

# Drop the rows where at least one element is missing.
updated_df = updated_df.dropna()

# %%
# Reset the index to ensure continuous numbering
updated_df = updated_df.reset_index(drop=True)

# %%
# Assuming 'columns_to_remove' 
reduce_columns = ["id", "Month Number"]

# Remove this specified columns
newupdated_df =updated_df.drop(columns=reduce_columns)

# Display the updated DataFrame
newupdated_df
# Out:
#               Segment                   Country     Product Discount Band  \
# 0          Government                    France      Paseo           Low
# 1           Midmarket                    France      Paseo           Low
# 2          Government                    Canada        VTT           Low
# 3          Government                    France      Paseo           Low
# 4          Government                    France       Velo           Low
# ..                ...                       ...         ...           ...
# 637        Enterprise                   Germany        VTT          High
# 638        Government                    Canada      Paseo          High
# 639        Government                    Mexico    Montana          High
# 640  Channel Partners  United States of America        VTT          High
# 641    Small Business                    Mexico   Amarilla          High
#
#     Units Sold  Manufacturing Price   Sale Price   Gross Sales  Discounts  \
# ...

# %%
newupdated_df.describe()
# Out:
#        Manufacturing Price   Sale Price    Gross Sales      Discounts  \
# count           642.000000    642.000000  6.420000e+02     642.000000
# mean             97.119938    120.526480  1.855083e+05   14282.839984
# std             108.568244    137.797292  2.571253e+05   23643.608658
# min               3.000000      7.000000  1.799000e+03      18.410000
# 25%               5.000000     12.000000  1.745175e+04    1038.587500
# 50%              10.000000     20.000000  3.900700e+04    3083.175000
# 75%             250.000000    300.000000  2.826750e+05   19261.125000
# max             260.000000    350.000000  1.207500e+06  149677.500000
#
#               Sales  Cost of Goods Sold         Profit
# count  6.420000e+02          642.000000     642.000000
# mean   1.712254e+05       147616.026480   26030.980981
# std    2.383121e+05       206004.271685   40679.164643
# min    1.655080e+03          918.000000     285.600000
# 25%    1.598608e+04         7548.000000    3974.130000
# ...

# %%
#list of countries in our dataset
newupdated_df['Country'].value_counts()
# Out:
# United States of America    132
# France                      130
# Mexico                      129
# Canada                      128
# Germany                     123
# Name: Country, dtype: int64

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
counts = newupdated_df['Country'].value_counts()
counts.plot(kind="bar")
plt.xlabel("Country")
plt.xticks(rotation=90)
plt.ylabel("Sales")

# Clear the figure to free up memory
plt.close(fig)

# Convert the chart to a base64-encoded string
chart_img = base64.b64encode(buffer.getvalue()).decode('utf-8')

    # Pass the base64-encoded chart image to the HTML template
return render_template('index.html', chart_img=chart_img)

plt.show()

# %%
# Convert float values to strings for the x-axis
x_axis = newupdated_df['Country'].astype(str)
y_axis = newupdated_df['Discounts']

# Create the bar plot
plt.bar(x_axis, y_axis, color='tab:blue', alpha=0.8, align='center')

# Set the xlabel and ylabel
plt.xlabel("Country")
plt.ylabel("Discounts")

# Rotate x-axis labels if needed
plt.xticks(rotation="vertical")

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='Discount Band', data=newupdated_df)

# Display count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.title('Count of Discount Band')
plt.xlabel('Discount Band')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## DATA VISUALIZATION ON WEB

# %%
# Fetch Data from API and Insert into MongoDB:

import requests, time
from pymongo import MongoClient

# mongodb+srv://admin:<password>@financialcluster.i4eijkg.mongodb.net/

# Check Connection to Database
try: 
    MongoClient() 
    print("Database Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 



# Connect to MongoDB
connectionString = "mongodb+srv://admin:Password123@financialcluster.i4eijkg.mongodb.net"
cluster = MongoClient(connectionString)
db = cluster['financialDB']
collection = db['financial']

# Pseudo-batch process

while True:
    # Fetch data from API
    api_url = "https://financial-data-api.laurelanalytiq.com/data.json"
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        try: 
            # Insert data into MongoDB
            collection.insert_many(data)
            print("Data Successfully uploaded to Database")
        except: 
            print("Error uploading data")
        print(data)
        time.sleep(1440)
else:
    exit()
# Out:
# Database Connected successfully!!!
# Data Successfully uploaded to Database
# ...

# %% [markdown]
# ## Create a Flask Web Application:

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

# @app.route('/about')
# def index():
#     return render_template('about.html')


# Dummy data for demonstration
#dummy_data = {'key': 'value'}

@app.route('/data')
def api_data():
    # Return the dummy data (replace with actual API request logic)
    return (data)


if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [05/Apr/2024 02:05:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2024 02:05:59] "GET /static/js/script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Apr/2024 02:06:00] "GET /static/css/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Apr/2024 02:06:00] "GET /static/assets/cogs.png HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Apr/2024 03:10:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2024 03:10:31] "GET /static/css/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Apr/2024 03:10:31] "GET /static/js/script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Apr/2024 03:10:31] "GET /static/assets/cogs.png HTTP/1.1" 304 -
