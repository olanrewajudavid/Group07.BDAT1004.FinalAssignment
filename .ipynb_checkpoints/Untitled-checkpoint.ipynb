# %%
# Import dependencies
import pandas as pd
import requests
from pymongo import MongoClient
import pymongo
from pprint import pprint
import csv
import json
from io import StringIO
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Connect to MongoDB server
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# confirm that our new database was created
print(client.list_database_names())
# Out:
# ['Bitcoin', 'Financial_Report', 'admin', 'classDB', 'config', 'fruits_db', 'local', 'uk_food']

# %%
# assign the database to a variable name
df= client['Financial_Report']

# %%
# Access the collection (replace 'data' with your collection name)
collection = df['data']

# %%
# Fetch all documents from the collection
cursor = collection.find({})

# %%
# Convert documents to list of dictionaries
documents = list(cursor)

# %%
# review a document in the financial collection
pprint(df.data.find_one())
# Out:
# {'  Sales ': ' $529,550.00 ',
#  ' COGS ': ' $393,380.00 ',
#  ' Discount Band ': ' None ',
#  ' Discounts ': ' $-   ',
#  ' Gross Sales ': ' $529,550.00 ',
#  ' Manufacturing Price ': ' $3.00 ',
#  ' Month Name ': ' December ',
#  ' Product ': ' Carretera ',
#  ' Profit ': ' $136,170.00 ',
#  ' Sale Price ': ' $350.00 ',
#  'Country': 'Germany',
#  'Date': '2014-12-01',
#  'Month Number': '12',
#  'Segment': 'Government',
#  'Units Sold': '1513',
#  'Year': '2014',
#  '_id': ObjectId('6603af8df1798c217086ca71')}

# %%
# Convert list of dictionaries to pandas DataFrame
data_df = pd.DataFrame(documents)
# Display DataFrame
data_df
# Out:
#                           _id           Segment                   Country  \
# 0    6603af8df1798c217086ca71        Government                   Germany
# 1    6603af8df1798c217086ca72        Government                    Canada
# 2    6603af8df1798c217086ca73    Small Business                    Mexico
# 3    6603af8df1798c217086ca74        Enterprise                    Canada
# 4    6603af8df1798c217086ca75  Channel Partners                   Germany
# ..                        ...               ...                       ...
# 696  6603af8df1798c217086cd29        Enterprise                   Germany
# 697  6603af8df1798c217086cd2a        Government                    Canada
# 698  6603af8df1798c217086cd2b        Government                    Mexico
# 699  6603af8df1798c217086cd2c  Channel Partners  United States of America
# 700  6603af8df1798c217086cd2d    Small Business                    Mexico
#
#         Product   Discount Band  Units Sold  Manufacturing Price   \
# 0     Carretera            None        1513                $3.00
# 1     Carretera            None      1618.5                $3.00
# 2       Montana            None         958                $5.00
# 3       Montana            None         345                $5.00
# 4       Montana            None        1545                $5.00
# ..           ...             ...        ...                   ...
# 696         VTT            High         552              $250.00
# 697       Paseo            High         723               $10.00
# 698     Montana            High        1368                $5.00
# 699         VTT            High        1806              $250.00
# 700    Amarilla            High         546              $260.00
#
#      Sale Price    Gross Sales     Discounts          Sales           COGS   \
# 0       $350.00    $529,550.00          $-      $529,550.00    $393,380.00
# 1        $20.00     $32,370.00          $-       $32,370.00     $16,185.00
# 2       $300.00    $287,400.00          $-      $287,400.00    $239,500.00
# 3       $125.00     $43,125.00          $-       $43,125.00     $41,400.00
# 4        $12.00     $18,540.00          $-       $18,540.00      $4,635.00
# ..           ...            ...           ...            ...            ...
# 696     $125.00     $69,000.00    $10,350.00     $58,650.00     $66,240.00
# 697       $7.00      $5,061.00       $759.15      $4,301.85      $3,615.00
# 698       $7.00      $9,576.00     $1,436.40      $8,139.60      $6,840.00
# 699      $12.00     $21,672.00     $3,250.80     $18,421.20      $5,418.00
# 700     $300.00    $163,800.00    $24,570.00    $139,230.00    $136,500.00
#
#            Profit         Date Month Number  Month Name   Year
# 0     $136,170.00   2014-12-01           12    December   2014
# 1      $16,185.00   2014-01-01            1     January   2014
# 2      $47,900.00   2014-08-01            8      August   2014
# 3       $1,725.00   2013-10-01           10     October   2013
# 4      $13,905.00   2014-06-01            6        June   2014
# ..             ...         ...          ...          ...   ...
# 696    $(7,590.00)  2014-11-01           11    November   2014
# 697       $686.85   2014-04-01            4       April   2014
# 698     $1,299.60   2014-02-01            2    February   2014
# 699    $13,003.20   2014-05-01            5         May   2014
# 700     $2,730.00   2014-10-01           10     October   2014
#
# [701 rows x 17 columns]

# %%
#colums to remove $ sign
columns_to_clean = [' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ', '  Sales ',' COGS ', ' Profit ']

# Loop through the columns and remove non-numeric characters
for col in columns_to_clean:
    data_df[col] = pd.to_numeric(data_df[col].replace('[^0-9\.-]', '', regex=True), errors='coerce')

# %%
#printing out the columns to reduce it
print(data_df.columns)
# Out:
# Index(['_id', 'Segment', 'Country', ' Product ', ' Discount Band ',
#        'Units Sold', ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ',
#        ' Discounts ', '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
# Rename columns for readability
updated_df = data_df.rename(columns={"_id": "id",
                                                  "Segment": "Segment",
                                                  "Country": "Country",
                                                  " Product ": "Product",
                                                  " Discount Band ": "Discount Band",
                                                  "Units Sold": "Units Sold",
                                                  " Manufacturing Price ": "Manufacturing Price",
                                                  "Sale Price": "Sale Price",
                                                  " Gross Sales ": "Gross Sales",
                                                  " Discounts ": "Discounts",
                                                  "  Sales ": "Sales",
                                                  " COGS ": "Cost of Goods Sold",
                                                  " Profit ": "Profit",
                                                  "Date": "Date",
                                                  "Month Number": "Month Number",
                                                  " Month Name ": "Month Name",
                                                  "Year": "Year"
                                                })
updated_df
# Out:
#                            id           Segment                   Country  \
# 0    6603af8df1798c217086ca71        Government                   Germany
# 1    6603af8df1798c217086ca72        Government                    Canada
# 2    6603af8df1798c217086ca73    Small Business                    Mexico
# 3    6603af8df1798c217086ca74        Enterprise                    Canada
# 4    6603af8df1798c217086ca75  Channel Partners                   Germany
# ..                        ...               ...                       ...
# 696  6603af8df1798c217086cd29        Enterprise                   Germany
# 697  6603af8df1798c217086cd2a        Government                    Canada
# 698  6603af8df1798c217086cd2b        Government                    Mexico
# 699  6603af8df1798c217086cd2c  Channel Partners  United States of America
# 700  6603af8df1798c217086cd2d    Small Business                    Mexico
#
#          Product Discount Band Units Sold  Manufacturing Price   Sale Price   \
# 0     Carretera          None        1513                  3.0         350.0
# 1     Carretera          None      1618.5                  3.0          20.0
# 2       Montana          None         958                  5.0         300.0
# 3       Montana          None         345                  5.0         125.0
# 4       Montana          None        1545                  5.0          12.0
# ..           ...           ...        ...                  ...           ...
# 696         VTT          High         552                250.0         125.0
# 697       Paseo          High         723                 10.0           7.0
# 698     Montana          High        1368                  5.0           7.0
# 699         VTT          High        1806                250.0          12.0
# 700    Amarilla          High         546                260.0         300.0
#
#      Gross Sales  Discounts      Sales  Cost of Goods Sold     Profit  \
# 0       529550.0        NaN  529550.00            393380.0  136170.00
# 1        32370.0        NaN   32370.00             16185.0   16185.00
# 2       287400.0        NaN  287400.00            239500.0   47900.00
# 3        43125.0        NaN   43125.00             41400.0    1725.00
# 4        18540.0        NaN   18540.00              4635.0   13905.00
# ..           ...        ...        ...                 ...        ...
# 696      69000.0   10350.00   58650.00             66240.0    7590.00
# 697       5061.0     759.15    4301.85              3615.0     686.85
# 698       9576.0    1436.40    8139.60              6840.0    1299.60
# 699      21672.0    3250.80   18421.20              5418.0   13003.20
# 700     163800.0   24570.00  139230.00            136500.0    2730.00
#
#            Date Month Number  Month Name  Year
# 0    2014-12-01           12   December   2014
# 1    2014-01-01            1    January   2014
# 2    2014-08-01            8     August   2014
# 3    2013-10-01           10    October   2013
# 4    2014-06-01            6       June   2014
# ..          ...          ...         ...   ...
# 696  2014-11-01           11   November   2014
# 697  2014-04-01            4      April   2014
# 698  2014-02-01            2   February   2014
# 699  2014-05-01            5        May   2014
# 700  2014-10-01           10    October   2014
#
# [701 rows x 17 columns]

# %%
# Assuming 'columns_to_remove' 
reduce_columns = ["id", "Month Number"]

# Remove this specified columns
newupdated_df =updated_df.drop(columns=reduce_columns)

# Display the updated DataFrame
newupdated_df
# Out:
#               Segment                   Country      Product Discount Band  \
# 0          Government                   Germany   Carretera          None
# 1          Government                    Canada   Carretera          None
# 2      Small Business                    Mexico     Montana          None
# 3          Enterprise                    Canada     Montana          None
# 4    Channel Partners                   Germany     Montana          None
# ..                ...                       ...          ...           ...
# 696        Enterprise                   Germany         VTT          High
# 697        Government                    Canada       Paseo          High
# 698        Government                    Mexico     Montana          High
# 699  Channel Partners  United States of America         VTT          High
# 700    Small Business                    Mexico    Amarilla          High
#
#     Units Sold  Manufacturing Price   Sale Price   Gross Sales  Discounts  \
# 0         1513                  3.0         350.0     529550.0        NaN
# 1       1618.5                  3.0          20.0      32370.0        NaN
# 2          958                  5.0         300.0     287400.0        NaN
# 3          345                  5.0         125.0      43125.0        NaN
# 4         1545                  5.0          12.0      18540.0        NaN
# ..         ...                  ...           ...          ...        ...
# 696        552                250.0         125.0      69000.0   10350.00
# 697        723                 10.0           7.0       5061.0     759.15
# 698       1368                  5.0           7.0       9576.0    1436.40
# 699       1806                250.0          12.0      21672.0    3250.80
# 700        546                260.0         300.0     163800.0   24570.00
#
#          Sales  Cost of Goods Sold     Profit        Date  Month Name  Year
# 0    529550.00            393380.0  136170.00  2014-12-01   December   2014
# 1     32370.00             16185.0   16185.00  2014-01-01    January   2014
# 2    287400.00            239500.0   47900.00  2014-08-01     August   2014
# 3     43125.00             41400.0    1725.00  2013-10-01    October   2013
# 4     18540.00              4635.0   13905.00  2014-06-01       June   2014
# ..         ...                 ...        ...         ...         ...   ...
# 696   58650.00             66240.0    7590.00  2014-11-01   November   2014
# 697    4301.85              3615.0     686.85  2014-04-01      April   2014
# 698    8139.60              6840.0    1299.60  2014-02-01   February   2014
# 699   18421.20              5418.0   13003.20  2014-05-01        May   2014
# 700  139230.00            136500.0    2730.00  2014-10-01    October   2014
#
# [701 rows x 15 columns]

# %%
updated_df.describe()
# Out:
#        Manufacturing Price   Sale Price    Gross Sales      Discounts  \
# count           700.000000    700.000000  7.000000e+02     647.000000
# mean             96.477143    118.428571  1.827594e+05   14227.586198
# std             108.602612    136.775515  2.542623e+05   23562.833079
# min               3.000000      7.000000  1.799000e+03      18.410000
# 25%               5.000000     12.000000  1.739175e+04    1061.000000
# 50%              10.000000     20.000000  3.798000e+04    3108.000000
# 75%             250.000000    300.000000  2.790250e+05   18809.250000
# max             260.000000    350.000000  1.207500e+06  149677.500000
#
#               Sales  Cost of Goods Sold         Profit
# count  7.000000e+02          700.000000     695.000000
# mean   1.696091e+05       145475.211429   26544.380993
# std    2.367263e+05       203865.506118   41515.104658
# min    1.655080e+03          918.000000     285.600000
# 25%    1.592800e+04         7490.000000    4013.630000
# 50%    3.554020e+04        22506.250000   11135.600000
# 75%    2.610775e+05       245607.500000   23918.500000
# max    1.159200e+06       950625.000000  262200.000000

# %%
#list of countries in our dataset
updated_df['Country'].value_counts()
# Out:
# Germany                     140
# Canada                      140
# Mexico                      140
# France                      140
# United States of America    140
# Name: Country, dtype: int64

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
counts = newupdated_df['Country'].value_counts()
counts.plot(kind="bar")
plt.xlabel("Country")
plt.xticks(rotation=90)
plt.ylabel("Sales")
plt.show()

# %%
# Convert float values to strings for the x-axis
x_axis = updated_df['Country'].astype(str)
y_axis = updated_df['Discounts']

# Create the bar plot
plt.bar(x_axis, y_axis, color='tab:blue', alpha=0.8, align='center')

# Set the xlabel and ylabel
plt.xlabel("Country")
plt.ylabel("Discounts")

# Rotate x-axis labels if needed
plt.xticks(rotation="vertical")

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='Discount Band', data=updated_df)

# Display count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.title('Count of Discount Band')
plt.xlabel('Discount Band')
plt.ylabel('Count')
plt.show()
